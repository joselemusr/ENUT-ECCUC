# %%
import pandas as pd

# %%
df_enut = pd.read_excel("ENUT-Reducida.xlsx")

# %%
df_enut
# Out:
#        o11_1_1  o11_1_2  o11_2_1  o11_2_2  o12_1_1  o12_1_2  o12_2_1  o12_2_2  \
# 0          2.0      NaN      2.0      NaN      2.0      NaN      2.0      NaN
# 1          1.0      1.0      1.0      1.5      1.0    0.167      1.0    0.083
# 2          2.0      NaN      2.0      NaN      1.0    0.083      2.0      NaN
# 3          2.0      NaN      2.0      NaN      2.0      NaN      2.0      NaN
# 4          2.0      NaN      2.0      NaN      2.0      NaN      2.0      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 34570      1.0      1.5      1.0      2.0      2.0      NaN      2.0      NaN
# 34571      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 34572      2.0      NaN      1.0      2.0      1.0    0.333      1.0    0.333
# 34573      2.0      NaN      1.0      0.5      2.0      NaN      1.0    0.333
# 34574      1.0      1.5      1.0      1.5      1.0    0.083      1.0    0.250
#
# ...
